# %% [markdown]
# ## Import NOAA list of weather stations

# %%
import pandas as pd
import re
from io import StringIO
import csv

# %%
def modify_text_file(input_txt, output_txt):
    # the NOAA txt-file doesn't contain any seperators.
    # Therefore we first add seperators to the txt-file
    # by counting the positions, where a seperator shall be inserted:
    positions_to_replace = [11, 20, 30, 37, 69, 75]
    
    with open(input_txt, 'r') as file:
        lines = file.readlines()

    modified_lines = []
    for line in lines:
        modified_line = list(line)
        
        for pos in positions_to_replace:
            if pos < len(modified_line):
                modified_line[pos] = ';;;'

        modified_lines.append(''.join(modified_line))

    with open(output_txt, 'w') as file:
        file.writelines(modified_lines)

# %%
# Example usage
input_txt = 'data/GHCNdaily_stations_share.txt'
output_txt = 'data/GHCNdaily_stations_sep.txt'
modify_text_file(input_txt, output_txt)
df = pd.read_csv(output_txt, sep=';;;', engine='python', names=['station_id','latitude','longitude','NN', 'station_name', 'GSN', 'five_no'])

# %%
df.head(2)
# Out:
#     station_id  latitude  longitude     NN                     station_name  \
# 0  GLW00017617   76.3833   -67.9167  701.0     CAMP TUTO EAST ASC S
# 1  GM000001153   51.9506     7.5914   62.0     MUENSTER
#
#      GSN  five_no
# 0             NaN
# 1         10313.0

# %%
# df.loc[df["station_name"].str.contains("LERCHENBERG")],["station_name", "latitude", "longitude"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1660 entries, 0 to 1659
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_id    1660 non-null   object
#  1   latitude      1660 non-null   float64
#  2   longitude     1660 non-null   float64
#  3   NN            1660 non-null   float64
#  4   station_name  1660 non-null   object
#  5   GSN           1659 non-null   object
#  6   five_no       394 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 90.9+ KB

# %% [markdown]
# # Basic Folium Map with Markers

# %%
# pip install folium

# %%
import folium

# folium map centered around station number (sj=1474)
map = folium.Map(location=[df['latitude'].iloc[1474], df['longitude'].iloc[1474]], zoom_start=11)

# Add markers for each station
for i, row in df.iterrows():
        folium.Marker([row['latitude'], row['longitude']], popup=row[['station_id', 'station_name']]
        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_150bad914e267c4ac4406c6e5d3c70d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_150bad914e267c4ac4406c6e5d3c70d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_150bad914e267c4ac4406c6e5d3c70d2 = L.map(
#                 &quot;map_150bad914e267c4ac4406c6e5d3c70d2&quot;,
#                 {
#                     center: [18.4496, -66.0772],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87751333713670bc8787ce51cbb57067 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_87751333713670bc8787ce51cbb57067.addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#             var marker_9ab0d390849c7efa21ad77dee48ac569 = L.marker(
#                 [76.3833, -67.9167],
#                 {}
#             ).addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#         var popup_bc48eb409af9cf0f46d3b5224b75fc13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66b44cfa79dcb05a5e3aac126d306d79 = $(`&lt;div id=&quot;html_66b44cfa79dcb05a5e3aac126d306d79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;station_id                          GLW00017617 station_name       CAMP TUTO EAST ASC S         Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_bc48eb409af9cf0f46d3b5224b75fc13.setContent(html_66b44cfa79dcb05a5e3aac126d306d79);
#
#
#
#         marker_9ab0d390849c7efa21ad77dee48ac569.bindPopup(popup_bc48eb409af9cf0f46d3b5224b75fc13)
#         ;
#
#
#
#
#             var marker_89a091227842e7d31ce56f413e1f0bab = L.marker(
#                 [51.9506, 7.5914],
#                 {}
#             ).addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#         var popup_667511cca5fcc677ec57440541125489 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_569a2f776a6774ba53ef6f90ab7051de = $(`&lt;div id=&quot;html_569a2f776a6774ba53ef6f90ab7051de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;station_id                          GM000001153 station_name       MUENSTER                     Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_667511cca5fcc677ec57440541125489.setContent(html_569a2f776a6774ba53ef6f90ab7051de);
#
#
#
#         marker_89a091227842e7d31ce56f413e1f0bab.bindPopup(popup_667511cca5fcc677ec57440541125489)
#         ;
#
#
#
#
#             var marker_02313bddd7322cddbd441f463cba73cf = L.marker(
#                 [53.1017, 8.7842],
#                 {}
#             ).addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#         var popup_847bc2e154e11799f7cd6e2afcd010b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c35513d14996a8036cc1303b7e02c15 = $(`&lt;div id=&quot;html_2c35513d14996a8036cc1303b7e02c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;station_id                          GM000001474 station_name       BREMEN-SEEFAHRTSCHULE        Name: 2, dtype: object&lt;/div&gt;`)[0];
#                 popup_847bc2e154e11799f7cd6e2afcd010b8.setContent(html_2c35513d14996a8036cc1303b7e02c15);
#
#
#
#         marker_02313bddd7322cddbd441f463cba73cf.bindPopup(popup_847bc2e154e11799f7cd6e2afcd010b8)
#         ;
#
#
#
#
#             var marker_67b34c7400106433d799e062ef8af35a = L.marker(
#                 [49.7517, 6.6467],
#                 {}
#             ).addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#         var popup_b8105300e6abc85eca4778c4dc1d92a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b55579a9286047b6ba9e8e6fe2f8ae4 = $(`&lt;div id=&quot;html_2b55579a9286047b6ba9e8e6fe2f8ae4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;station_id                          GM000002277 station_name       TRIER                        Name: 3, dtype: object&lt;/div&gt;`)[0];
#                 popup_b8105300e6abc85eca4778c4dc1d92a2.setContent(html_2b55579a9286047b6ba9e8e6fe2f8ae4);
#
#
#
#         marker_67b34c7400106433d799e062ef8af35a.bindPopup(popup_b8105300e6abc85eca4778c4dc1d92a2)
#         ;
#
#
#
#
#             var marker_9a7cd99d0ce89085620f93f72385c137 = L.marker(
#                 [49.4253, 7.7367],
#                 {}
#             ).addTo(map_150bad914e267c4ac4406c6e5d3c70d2);
#
#
#         var popup_187ef82a8df5e00ac1c1622742b06f24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f3a558fac6c8f9050ec14dfebb39d03 = $(`&lt;div id=&quot;html_5f3a558fac6c8f9050ec14dfebb39d03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;station_id                          GM000002288 station_name       KAISERSLAUTERN
